# %% [markdown]
# Assignment 1

# %% [markdown]
# 1. Question 1:
# Write a Python program to print your name and favourite colour on two
# separate lines.

# %%
print("Name: Vedantika Sukale")
print("Favourite Colour: Black")
# Out:
# Name: Vedantika Sukale
# Favourite Colour: Black

# %% [markdown]
# 2. Question 2:
# Write a Python program that prints the result of adding 7 and 8

# %%
result = 7 + 8
print("The result of adding 7 and 8 is:", result)
# Out:
# The result of adding 7 and 8 is: 15

# %% [markdown]
# Question 3:
# Use the print function to display the following text exactly as it is:

# %%
print("Python is fun! \nLet's learn together.")
# Out:
# Python is fun!
# Let's learn together.

# %% [markdown]
# Question 4:
# Write a Python program to calculate and print the result of multiplying 6 by
# 9.

# %%
result = 6 * 9
print("The result of multiplying 6 and 9 is:", result)
# Out:
# The result of multiplying 6 and 9 is: 54

# %% [markdown]
# Question 5:
# Write a Python program that prints the result of adding 5 + 5 and
# multiplying 2 * 3 in a single line of code.

# %%
print("5 + 5 =", 5 + 5, "and 2 * 3 =", 2 * 3)
# Out:
# 5 + 5 = 10 and 2 * 3 = 6

# %% [markdown]
# 1. Take the name A as input from the user and print "Hello A", where A is
# the name in input.

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: A
# Hello A

# %% [markdown]
# 2. You have x rupees in your savings. You google pay y rupees, print your
# bank balance

# %%
x = float(input("Enter your savings (in rupees): "))
y = float(input("Enter the amount to pay (in rupees): "))
balance = x - y
print("Your bank balance is:", balance, "rupees")
# Out:
# Enter your savings (in rupees): 500
# Enter the amount to pay (in rupees): 100
# Your bank balance is: 400.0 rupees

# %% [markdown]
# 3. Print the first five letters of the English alphabet i.e. A, B, C, D and E.
# one below each other

# %%
print("A\nB\nC\nD\nE")
# Out:
# A
# B
# C
# D
# E

# %% [markdown]
# 4. Take two names A and B as input from the user, and print "A says Hi to
# B" (Without quotations), where A and B are the names in input.

# %%
A = input("Enter the first name: ")
B = input("Enter the second name: ")

print(A, "says Hi to", B)
# Out:
# Enter the first name: A
# Enter the second name: B
# A says Hi to B
